# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import os
import sys
import torch

# %%
import tifffile as tiff
vol_rec = tiff.imread('/root/project/ckpt/complex_image_z14_y11_x17/reconstruction.tif')
plt.imshow(vol_rec[0, :, :], cmap='gray')
